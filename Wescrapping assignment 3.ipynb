# %%
#1st program

# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
driver = webdriver.Chrome(r"C:/Users/Vidhya/Downloads/chromedriver_win32/chromedriver.exe")

# %%
import warnings
warnings.simplefilter("ignore")

# %%
driver.get('https://www.amazon.in/')

# %%
search_product=driver.find_element_by_id('twotabsearchtextbox')
search_product.send_keys("Guitars")

# %%
search_btn=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search_btn.click()

# %%
#2nd program

# %%
Brand_Name=[]
Name_of_product=[]
Price_of_product=[]
Return_or_Exchange=[]
Expected_Delivery=[]
Availability=[]
Product_URL=[]

# %%
Brand_tags=driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']")
Brand_tags[0:48]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="15bb4b7a-9787-4e4e-9be3-a4be71ea0a17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="1f00f1fc-dd60-411e-ba19-6b9e35d88262")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="b21b4f7d-683f-4575-a168-9512972a126f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="5688efa9-2b49-43f7-9afd-d3fde801a396")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="93574f8a-f1f2-4144-bfbd-a125ba3ce25e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="418ed396-e68e-4a2a-9df7-f954833c2d74")>,
# ...

# %%
for i in Brand_tags:
    Brand=i.text
    Brand_Name.append(Brand)
Brand_Name[0:48]
# Out:
# ['Kadence Slowhand Premium Jumbo Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo and Guitar stand (Black Spruce Wood)',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence Guitar Acoustica Series, Electric Acoustic Guitar, Ash Wood with Pickup and Inbuilt tuner (Ash Wood, Electro Acoustic)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 38C with Bag, Strings, Pick and Strap, TBS Transparent Blue Sunburst',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
# ...

# %%
Brand_tags1=driver.find_elements_by_xpath("//span[@class='a-size-base-plus a-color-base a-text-normal']")
Brand_tags1[0:48]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="f476624e-b26d-4ed0-a31d-a28711289184")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="00d7ed9b-5605-4812-aa15-7b93599a1328")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="5fa0ba64-59d9-4e85-bbf3-1cc9b41f20e7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="bf31d36b-ff1e-4b1d-ac5e-d71b90f948a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="f4927634-0f02-40cc-ad06-f579269f8bf1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="22e48aa9-bc28-4160-9039-470840190c1f")>,
# ...

# %%
for i in Brand_tags1:
    Brand1=i.text
    Brand_Name.append(Brand1)
Brand_Name[0:48]
# Out:
# ['Kadence Slowhand Premium Jumbo Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo and Guitar stand (Black Spruce Wood)',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence Guitar Acoustica Series, Electric Acoustic Guitar, Ash Wood with Pickup and Inbuilt tuner (Ash Wood, Electro Acoustic)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 38C with Bag, Strings, Pick and Strap, TBS Transparent Blue Sunburst',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
# ...

# %%
Brand_tags2=driver.find_elements_by_xpath("//span[@class='a-size-base-plus a-color-base a-text-normal']")
Brand_tags2[0:48]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="428c5bdf-30ac-40e0-8c0d-61398b69dd24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="3e6eea9b-f6a7-4fb3-b171-629398dbae16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="fcad0c3c-b831-427e-b8be-471355f50cbe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="ae0ef5da-505a-425f-be54-826ffe7e2454")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="6fb3e89b-e102-4ac7-b2f3-29834aedc147")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="0450394c-a9dc-4fae-ac49-d8f69d190640")>,
# ...

# %%
for i in Brand_tags2:
    Brand2=i.text
    Brand_Name.append(Brand2)
Brand_Name[0:48]
# Out:
# ['Kadence Slowhand Premium Jumbo Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo and Guitar stand (Black Spruce Wood)',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence Guitar Acoustica Series, Electric Acoustic Guitar, Ash Wood with Pickup and Inbuilt tuner (Ash Wood, Electro Acoustic)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 38C with Bag, Strings, Pick and Strap, TBS Transparent Blue Sunburst',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
# ...

# %%
Price_tags=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
Price_tags[0:48]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="8bbcf433-890b-4432-8447-dc6ee81ea743")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="f2162258-c254-4190-b361-8b3b8edbf1f1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="75d7ed7e-3792-46cf-a7f0-3a2faddde8ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="69abe0cb-ff57-4fd7-a706-ead7792599c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="ebf15e6e-b691-4f55-8559-9ba269f7f099")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="6cdb2592-3383-4807-b417-cdd7db399b94")>,
# ...

# %%
for i in Price_tags:
    Price1=i.text
    Price_of_product.append(Price1)
Price_of_product[0:48]
# Out:
# ['5,999',
#  '7,299',
#  '7,348',
#  '10,499',
#  '2,190',
#  '5,199',
#  '7,299',
#  '2,649',
#  '2,350',
#  '2,649',
#  '7,299',
#  '13,499',
#  '10,499',
#  '',
#  '2,190',
#  '2,090',
#  '2,599',
#  '2,599',
#  '2,749',
#  '4,180',
#  '5,199',
#  '7,349',
#  '11,499',
#  '2,649',
#  '5,999',
#  '9,389',
#  '2,514',
#  '7,599',
#  '2,895',
#  '10,250',
#  '989',
#  '2,625',
#  '3,599',
#  '2,518',
#  '7,999',
#  '7,400',
#  '51,189',
#  '13,999',
#  '4,490',
#  '2,649',
#  '3,299',
#  '11,490',
#  '2,649',
#  '5,999',
#  '7,299',
#  '2,190',
#  '9,490',
#  '4,699']

# %%
Return_tags=driver.find_elements_by_xpath("/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[22]/div[2]/div/div/div/div[2]/span/div[2]/a")
Return_tags[0:48]
# Out:
# []

# %%
for i in Return_tags:
    Return=i.text
    Return_or_Exchange.append(Return)
Return_or_Exchange[0:48]
# Out:
# []

# %%
Delivery_tags=driver.find_elements_by_xpath("//span[@class='a-text-bold']")
Delivery_tags[0:48]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="753d01a0-7e2d-493e-acaa-d2c5915e23bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="7519fc93-7401-4597-88ed-99abc5b8c9a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="d464c6c5-c92a-41c4-9b16-58e63c77b2cc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="5086fc55-4e74-4eb8-a93e-58b9e78c294e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="c85c7878-f647-4b5a-a294-e6463c624e98")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="ca1152f3-2aff-4554-86a5-0bb24eb07df2")>,
# ...

# %%
for i in Delivery_tags:
    Delivery=i.text
    Expected_Delivery.append(Delivery)
Expected_Delivery[0:48]
# Out:
# ['Friday, December 31',
#  'Saturday, January 1',
#  'Tomorrow, December 30',
#  'Friday, December 31',
#  'Friday, December 31',
#  'Tomorrow, December 30',
#  'Tomorrow, December 30',
#  'Friday, December 31',
#  'Saturday, January 1',
#  'Tomorrow, December 30',
#  'Saturday, January 1',
#  'Tomorrow, December 30',
#  'Saturday, January 1',
#  'Sunday, January 2',
#  'Tomorrow, December 30',
#  'Friday, December 31',
#  'Friday, December 31',
#  'Tomorrow, December 30',
#  'Friday, December 31',
#  'Saturday, January 1',
#  'Saturday, January 1',
#  'Tomorrow, December 30',
#  'Monday, January 3',
#  'Saturday, January 1',
#  'Tuesday, January 4',
#  'Monday, January 10',
#  'Saturday, January 1',
#  'Saturday, January 1',
#  'Friday, December 31',
#  'Friday, December 31',
#  'Tomorrow, December 30',
#  'Tomorrow, December 30',
#  'Sunday, January 2',
#  'Sunday, January 2',
#  'Tomorrow, December 30',
#  'Friday, December 31',
#  'Monday, January 3',
#  'Tomorrow, December 30',
# ...

# %%
Product_URL_tags=driver.find_elements_by_xpath("//a[@class='a-link-normal s-link-style a-text-normal']")
Product_URL_tags[0:48]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="7fdaf253-2437-4aaf-a5ff-8a33b6c3cf48")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="9f5495d7-18d0-4ab2-9879-b875627aa2cc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="fba65fb2-75b4-4d58-8ec1-c58ac6cf3aea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="50433d3d-0265-45b9-8ab5-78094bf2dfa8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="6b11d9a4-28b8-46af-ab5c-39615d55f8ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="451e015e-20f7-424d-9987-8af832251047")>,
# ...

# %%
for i in Product_URL_tags:
    Product=i.text
    Product_URL.append(Product)
Product_URL[0:48]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="7fdaf253-2437-4aaf-a5ff-8a33b6c3cf48")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="9f5495d7-18d0-4ab2-9879-b875627aa2cc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="fba65fb2-75b4-4d58-8ec1-c58ac6cf3aea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="50433d3d-0265-45b9-8ab5-78094bf2dfa8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="6b11d9a4-28b8-46af-ab5c-39615d55f8ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45e74015e7db68f50bb159977ff89a2c", element="451e015e-20f7-424d-9987-8af832251047")>,
# ...

# %%
print(len(Brand_Name),len(Price_of_product),len(Return_or_Exchange),len(Expected_Delivery),len(Availability),len(Product_URL))
# Out:
# 0 64 0 59 0 126

# %%
Products=pd.DataFrame({})
Products["Brand Name"]=Brand_Name
Products["Price of the product"]=Price_of_product
Products["Return or Exchange"]=Return_or_Exchange
Products["Expected Delivery"]=Expected_Delivery
Products["Availability"]=Availability
Products["Product URL"]=Product_URL
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-01db84880ba7> in <module>
#       2 Products["Brand Name"]=Brand_Name
#       3 Products["Price of the product"]=Price_of_product
# ----> 4 Products["Return or Exchange"]=Return_or_Exchange
#       5 Products["Expected Delivery"]=Expected_Delivery
#       6 Products["Availability"]=Availability
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
# ...

# %%
#3rd program

# %%
driver = webdriver.Chrome(r"C:/Users/Vidhya/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://images.google.com/')

# %%
search_fruits=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[2]/div[2]/input")
search_fruits.send_keys("fruits")

# %%
search_btn=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
search_btn.click()

# %%
fruits_tags=driver.find_elements_by_xpath("/html/body/div[2]/c-wiz/div[3]/div[1]/div/div/div/div[1]/div[1]/span/div[1]/div[1]/div[1]/a[1]/div[1]/img")
fruits_tags[0:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d96359e7fc24dbb1d6229a0edb71859c", element="6070bf0d-82b1-4266-bdc1-915d4e697b5e")>]

# %%
Fruits=[]
Cars=[]
Machine_Learning=[]
Guitar=[]
Cakes=[]

# %%
for i in fruits_tags:
    fruits1=i.text
    Fruits.append(fruits1)
Fruits[0:10]
# Out:
# ['']

# %%
# !pip install bs4
# !pip install requests

# %%
#4th program

# %%
driver = webdriver.Chrome(r"C:/Users/Vidhya/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
search_mobile=driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
search_mobile.send_keys("Oneplus Nord")

# %%
search_btn=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn.click()

# %%
Brand_Name=[]
Smartphone_Name=[]
Color_of_product=[]
RAM=[]
Storage_ROM=[]
Primary_Camera=[]
Secondary_Camera=[]
Display_Size=[]
Battery_Capacity=[]
Price_of_Product=[]
Product_URL=[]

# %%
Brand_tags=driver.find_elements_by_xpath("//a[@class='s1Q9rs']")
Brand_tags[0:40]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="1fb8c450-4a60-4321-b61c-9042d835c053")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="d10ad3e4-d4c5-4627-a4bb-d25dd6ff2530")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="6dfae89a-b3de-4135-8cb9-993226d7fefb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="94cea5b8-6184-499f-b777-9503a2355c82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="d54bcb6e-6133-4ae3-89c1-d77cffbd2e9f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="1f6b0e5d-0bb9-4fdf-88bf-1d7a3e098997")>,
# ...

# %%
for i in Brand_tags:
    Brand=i.text
    Brand_Name.append(Brand)
Brand_Name[0:40]
# Out:
# ['Micvir Back Cover for OnePlus Nord 2 5G',
#  'Tommcase Back Cover for Oneplus Nord 2 5g',
#  'Micvir Back Cover for OnePlus Nord CE 5G',
#  'Cover Alive Back Cover for OnePlus Nord 2 5G',
#  'KARWAN Back Cover for OnePlus Nord CE 5G',
#  'OnePlus 65 Watt Warp Charger Power Adapter With Type-C ...',
#  'Firstkart Front and Back Tempered Glass for Oneplus Nor...',
#  'ZINJURIKI Back Screen Guard for Oneplus Nord',
#  'SHINESTAR. Back Cover for OnePlus Nord CE 5G, OnePlus N...',
#  'Flipkart SmartBuy Back Cover for OnePlus Nord CE 5G',
#  'Cover Alive Back Cover for OnePlus Nord CE 5G, OnePlus ...',
#  'KARWAN Back Cover for OnePlus Nord 2 5G',
#  'KWINE CASE Back Cover for OnePlus Nord 2 5G',
#  'COSHIBA Edge To Edge Tempered Glass for Oneplus Nord',
#  'I THINK ENTERPRISES Back Screen Guard for Oneplus Nord',
#  'ENOLA Back Screen Guard for Oneplus Nord',
#  'KWINE CASE Back Cover for OnePlus Nord',
#  'Bonqo Back Cover for Oneplus Nord',
# ...

# %%
Color_tags=driver.find_elements_by_xpath("//div[@class='_3Djpdu']")
Color_tags[0:40]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="8dd857a3-0ac8-47f5-9dfd-0b8efab43975")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="bd7c2110-5da3-4745-a7a0-445cda52be12")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="d7ec68d5-1b2d-40d4-830f-6210aa341db1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="7f469bb9-c297-4a59-97fa-107a00979bf1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="f836013f-407b-4840-8f47-6ab384e3c4a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="f20c9580-755d-4cba-afbb-0e194d3e78f5")>,
# ...

# %%
for i in Color_tags:
    Color=i.text
    Color_of_product.append(Color)
Color_of_product[0:40]
# Out:
# ['Transparent, Black',
#  'Black, Shock Proof',
#  'Transparent, Black',
#  'Black, Transparent, Camera Bump Protector',
#  'Blue, Shock Proof, Silicon',
#  'White',
#  'Pack of 2',
#  'Pack of 1',
#  'Blue',
#  'Red, Rugged Armor',
#  'Black, Camera Bump Protector',
#  'Green, Gold, Transparent, Shock Proof, Silicon',
#  'Black, Shock Proof',
#  'Pack of 1',
#  'Pack of 1',
#  'Pack of 1',
#  'Black, Rugged Armor',
#  'Blue, Dual Protection, Silicon',
#  'Black, Shock Proof',
#  'Green, Grip Case',
#  'White, Flexible, Silicon',
#  'Pack of 2',
#  'Pack of 2',
#  'Pack of: 2',
#  'Purple, Grip Case',
#  'Blue, Shock Proof',
#  'Black, Shock Proof, Silicon',
#  'Black, Shock Proof, Silicon',
#  'Pink, White, Grip Case',
#  'Pack of 1',
#  'Black, Transparent, Grip Case',
#  'Black',
#  'Black',
#  'Transparent, Grip Case',
#  'Black, Gold, Transparent, Shock Proof, Silicon',
#  'Red, Hard Case',
#  'Pack of 2',
#  'Pack of 2',
#  'Black, Transparent, Grip Case',
# ...

# %%
Price_tags=driver.find_elements_by_xpath("//a[@class='_8VNy32']")
Price_tags[0:40]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="0faff936-33bf-4ffe-8570-16011c9b470e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="3e0bad10-e2fa-458c-923c-08432960c584")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="342e87a7-1206-4484-9f43-8aed2119aed4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="c2861668-332b-451c-a844-cafe31859db7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="ad90b844-4a36-4f0c-ba1b-2e9016e38956")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="ac34c7e5-ad5e-408d-849e-7207dd6c1302")>,
# ...

# %%
for i in Price_tags:
    Price=i.text
    Price_of_Product.append(Price)
Price_of_Product[0:40]
# Out:
# ['₹204₹99979% off',
#  '₹549₹1,29957% off\nFree delivery',
#  '₹169₹99983% off',
#  '₹175₹69974% off',
#  '₹499₹99950% off',
#  '₹2,799₹5,99953% off',
#  '₹139₹49972% off',
#  '₹110₹39972% off',
#  '₹259₹99974% off',
#  '₹199₹1,19983% off',
#  '₹178₹69974% off',
#  '₹499₹99950% off',
#  '₹249₹1,19979% off',
#  '₹128₹59978% off',
#  '₹98₹49980% off',
#  '₹139₹39965% off',
#  '₹259₹1,19978% off',
#  '₹199₹79975% off',
#  '₹165₹69976% off',
#  '₹259₹69962% off',
#  '₹399₹99960% off',
#  '₹139₹49972% off',
#  '₹139₹49972% off',
#  '₹104₹69985% off',
#  '₹259₹69962% off',
#  '₹599₹1,19950% off\nFree delivery',
#  '₹499₹99950% off',
#  '₹499₹99950% off',
#  '₹199₹99980% off',
#  '₹249₹99975% off',
#  '₹239₹59960% off',
#  '₹200₹99979% off',
#  '₹259₹99974% off',
#  '₹179₹69974% off',
#  '₹499₹99950% off',
#  '₹259₹1,19978% off',
#  '₹159₹49968% off',
#  '₹159₹49968% off',
#  '₹197₹65069% off',
#  '₹189₹99981% off']

# %%
URL_tags=driver.find_elements_by_xpath("//a[@class='s1Q9rs']")
URL_tags[0:40]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="1fb8c450-4a60-4321-b61c-9042d835c053")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="d10ad3e4-d4c5-4627-a4bb-d25dd6ff2530")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="6dfae89a-b3de-4135-8cb9-993226d7fefb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="94cea5b8-6184-499f-b777-9503a2355c82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="d54bcb6e-6133-4ae3-89c1-d77cffbd2e9f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="180ba9f8ec8cc45a4541d2c43cb12958", element="1f6b0e5d-0bb9-4fdf-88bf-1d7a3e098997")>,
# ...

# %%
for i in URL_tags:
    URL=i.text
    Product_URL.append(URL)
Product_URL[0:40]
# Out:
# ['Micvir Back Cover for OnePlus Nord 2 5G',
#  'Tommcase Back Cover for Oneplus Nord 2 5g',
#  'Micvir Back Cover for OnePlus Nord CE 5G',
#  'Cover Alive Back Cover for OnePlus Nord 2 5G',
#  'KARWAN Back Cover for OnePlus Nord CE 5G',
#  'OnePlus 65 Watt Warp Charger Power Adapter With Type-C ...',
#  'Firstkart Front and Back Tempered Glass for Oneplus Nor...',
#  'ZINJURIKI Back Screen Guard for Oneplus Nord',
#  'SHINESTAR. Back Cover for OnePlus Nord CE 5G, OnePlus N...',
#  'Flipkart SmartBuy Back Cover for OnePlus Nord CE 5G',
#  'Cover Alive Back Cover for OnePlus Nord CE 5G, OnePlus ...',
#  'KARWAN Back Cover for OnePlus Nord 2 5G',
#  'KWINE CASE Back Cover for OnePlus Nord 2 5G',
#  'COSHIBA Edge To Edge Tempered Glass for Oneplus Nord',
#  'I THINK ENTERPRISES Back Screen Guard for Oneplus Nord',
#  'ENOLA Back Screen Guard for Oneplus Nord',
#  'KWINE CASE Back Cover for OnePlus Nord',
#  'Bonqo Back Cover for Oneplus Nord',
# ...

# %%
print(len(Brand_Name),len(Color_of_product),len(Price_of_Product),len(Product_URL))
# Out:
# 40 40 40 40

# %%
products=pd.DataFrame({})
products["Brand Name"]=Brand_Name
products["Color of product"]=Color_of_product
products["Price of product"]=Price_of_Product
products["Product URL"]=Product_URL

# %%
products
# Out:
#                                            Brand Name  \
# 0             Micvir Back Cover for OnePlus Nord 2 5G
# 1           Tommcase Back Cover for Oneplus Nord 2 5g
# 2            Micvir Back Cover for OnePlus Nord CE 5G
# 3        Cover Alive Back Cover for OnePlus Nord 2 5G
# 4            KARWAN Back Cover for OnePlus Nord CE 5G
# 5   OnePlus 65 Watt Warp Charger Power Adapter Wit...
# 6   Firstkart Front and Back Tempered Glass for On...
# 7        ZINJURIKI Back Screen Guard for Oneplus Nord
# 8   SHINESTAR. Back Cover for OnePlus Nord CE 5G, ...
# 9   Flipkart SmartBuy Back Cover for OnePlus Nord ...
# 10  Cover Alive Back Cover for OnePlus Nord CE 5G,...
# 11            KARWAN Back Cover for OnePlus Nord 2 5G
# 12        KWINE CASE Back Cover for OnePlus Nord 2 5G
# 13  COSHIBA Edge To Edge Tempered Glass for Oneplu...
# 14  I THINK ENTERPRISES Back Screen Guard for Onep...
# 15           ENOLA Back Screen Guard for Oneplus Nord
# ...

# %%
#5th program

# %%
driver = webdriver.Chrome(r"C:/Users/Vidhya/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.google.com/maps/@17.5109048,78.5092874,15z')

# %%
search_city=driver.find_element_by_id('searchboxinput')
search_city.send_keys("Chennai")

# %%
search_btn=driver.find_element_by_xpath("//button[@class='nhb85d-BIqFsb']")
search_btn.click()

# %%
#6th program

# %%
driver = webdriver.Chrome(r"C:/Users/Vidhya/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://trak.in/')

# %%
search_btn=driver.find_element_by_xpath("/html/body/div[1]/header/div[2]/div/div/div/div/nav/ul/li[9]")
search_btn.click()

# %%
search_btn=driver.find_elements_by_xpath("/html/body/div[1]/header/div[2]/div/div/div/div/nav/ul/li[9]/ul/li[1]/a")
search_btn.click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-c92f6f686e57> in <module>
#       1 search_btn=driver.find_elements_by_xpath("/html/body/div[1]/header/div[2]/div/div/div/div/nav/ul/li[9]/ul/li[1]/a")
# ----> 2 search_btn.click()
#
# AttributeError: 'list' object has no attribute 'click'

# %%
title_tags=driver.find_elements_by_xpath("//div[@class='dataTables_wrapper no-footer']")
title_tags[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6d45d2ee1df597c509ae46d63e7d3118", element="8a10995e-9bb8-432d-8e9c-f9f0fe912cc5")>]

# %%
Jan_deals=[]
Feb_deals=[]
March_deals=[]

# %%
for i in title_tags:
    Jan=i.text
    Jan_deals.append(Jan)
Jan_deals[0:1]
# Out:
# ["Show\n10\n25\n50\n100\nentries\nSearch:\nSr. No. Date (dd/mm/yyyy) Startup Name Industry / Vertical Sub-Vertical City / Location Investors' Name Investment Type Amount (In USD)\n1 01/04/2021 BYJU’S Edu-tech Online tutoring Bengaluru Innoven Capital Series F 460,000,000\n2 05/04/2021 Meesho E-commerce Online reselling platform Bengaluru SoftBank Vision Fund 2 Series E 300,000,000\n3 14/04/2021 Swiggy Online Food Delivery Online Food Delivery Bengaluru Amansa Holdings, Carmignac, Falcon Edge Capital, Goldman Sachs, Think Investments Series J 343,000,000\n4 07/04/2021 Groww FinTech Investment platform Bengaluru MC Global Edtech, B Capital, Baron, others Series D 83,000,000\n5 14/04/2021 Beldara E-commerce Global B2B marketplace Mumbai Hindustan Media Ventures Venture 7,400,000\nShowing 1 to 5 of 5 entries\nPreviousNext"]

# %%
Feb_tags=driver.find_elements_by_xpath("//div[@class='dataTables_scrollBody']")
Feb_tags[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6d45d2ee1df597c509ae46d63e7d3118", element="1ac01a52-5679-4365-bc8b-c0252ea174b8")>]

# %%
for i in Feb_tags:
    Feb=i.text
    Feb_deals.append(Feb)
Feb_deals[0:1]
# Out:
# ['1 01/04/2021 BYJU’S Edu-tech Online tutoring Bengaluru Innoven Capital Series F 460,000,000\n2 05/04/2021 Meesho E-commerce Online reselling platform Bengaluru SoftBank Vision Fund 2 Series E 300,000,000\n3 14/04/2021 Swiggy Online Food Delivery Online Food Delivery Bengaluru Amansa Holdings, Carmignac, Falcon Edge Capital, Goldman Sachs, Think Investments Series J 343,000,000\n4 07/04/2021 Groww FinTech Investment platform Bengaluru MC Global Edtech, B Capital, Baron, others Series D 83,000,000\n5 14/04/2021 Beldara E-commerce Global B2B marketplace Mumbai Hindustan Media Ventures Venture 7,400,000']

# %%
March_tags=driver.find_elements_by_xpath("/html/body/div[1]/main/div/div/div/div[2]/div[1]/div/div/div/div[1]/div/div[3]")
March_tags[0:1]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6d45d2ee1df597c509ae46d63e7d3118", element="d34dbd1b-e2c5-4ca0-8970-ad0ae8d71a80")>]

# %%
for i in March_tags:
    March=i.text
    March_deals.append(March)
March_deals[0:1]
# Out:
# ["Show\n10\n25\n50\n100\nentries\nSearch:\nSr. No. Date (dd/mm/yyyy) Startup Name Industry / Vertical Sub-Vertical City / Location Investors' Name Investment Type Amount (In USD)\n1 04/03/2021 DealShare E-commerce Online shopping platform Jaipur, Rajasthan Innoven Capital Debt Financing 250,000,000\n2 31/03/2021 Uniphore Technology Conversational Service Automation (CSA) Palo Alto Sorenson Capital Partners Series D 140,000,000\n3 30/03/2021 Dunzo E-commerce Hyper-local delivery app Bengaluru Krishtal Advisors Pte Ltd Series E 8,000,000\n4 30/03/2021 BYJU’S Edu-tech Online tutoring Bengaluru MC Global Edtech, B Capital, Baron, others Series F 460,000,000\n5 23/03/2021 SkilloVilla Edu-tech Career and job-oriented upskilling. Bengaluru Titan Capital, others Seed 300,000,000\n6 25/03/2021 CityMall E-commerce Social ecommerce and online grocery platform Gurgaon Accel Partners Series A 11,000,000\n7 26/03/2021 DotPe FinTech Commerce and payments platform to offline enterprise businesses. G
# ...

# %%
#7th program

# %%
driver = webdriver.Chrome(r"C:/Users/Vidhya/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.digit.in/')

# %%
search_btn=driver.find_element_by_xpath("/html/body/div[3]/div/div[3]/div[2]/div[4]/ul/li[9]/a")
search_btn.click()

# %%
laptop_tags=driver.find_elements_by_xpath("//div[@class='Section-center']")
laptop_tags[0:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ad5cf7168947ad328d4b2347e3ee280f", element="33973741-f6b5-4aa8-a379-95cdb8ad470e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ad5cf7168947ad328d4b2347e3ee280f", element="4ebdb476-28d8-4d9c-b778-4b502036ef55")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ad5cf7168947ad328d4b2347e3ee280f", element="d5b03ea3-dea1-4e2e-861a-ae8aa4257d7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ad5cf7168947ad328d4b2347e3ee280f", element="9e814cfe-2c91-46b4-9ac4-34288f162c00")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ad5cf7168947ad328d4b2347e3ee280f", element="d7f1a98d-b25f-4979-9d23-40108fdf1ad3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ad5cf7168947ad328d4b2347e3ee280f", element="07a47216-ad50-4957-9d60-986f5f657082")>,
# ...

# %%
laptop_details=[]

# %%
for i in laptop_tags:
    laptop=i.text
    laptop_details.append(laptop)
laptop_details[0:10]
# Out:
# ['Possibly the best value-for-money gaming laptop on the market, the Acer Nitro 5 checks all the right boxes. It features an ultra-fast Ryzen 9 Octa-Core processor paired with an RTX 3070 GPU. The high-end gaming laptop comes with 16GB RAM, 256GB SSD, 1TB SSD and a 15.6-inch FHD display.\nSPECIFICATION\nOS : Windows 10\nDisplay : 15.6" (1920 x 1080)\nProcessor : AMD Ryzen 9 Octa Core | 2.4 GHz\nMemory : 1 TB HDD/16 GBGB DDR4\nWeight : 2.4\nDimension : 363.4 x 255 x 23.9\nGraphics Processor : NVIDIA GeForce RTX 3070\nAVAILABLE ₹ 129,990\nBUY NOW',
# ...

# %%
#8th program

# %%
driver = webdriver.Chrome(r"C:/Users/Vidhya/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.forbes.com/?sh=72482cea2254')

# %%
search_btn=driver.find_element_by_xpath("//button[@class='icon--search']")
search_btn.click()

# %%
search_data=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/input")
search_data.send_keys("Top 10 billionaires")

# %%
search_btn=driver.find_element_by_xpath("//button[@class='search-modal__submit']")
search_btn.click()

# %%
search_btn=driver.find_element_by_xpath("/html/body/div[1]/main/div[1]/div[1]/div[4]/div/article[15]/div[1]/h3/a")
search_btn.click()

# %%
#9th program

# %%
driver = webdriver.Chrome(r"C:/Users/Vidhya/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.youtube.com/')

# %%
search_btn=driver.find_element_by_xpath("/html/body/ytd-app/div/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-rich-grid-renderer/div[6]/ytd-rich-grid-row[1]/div/ytd-rich-item-renderer[1]/div/ytd-rich-grid-media/div[1]/div[2]/div[1]")
search_btn.click()

# %%
Comments=[]
Comment_upvote=[]
Time_of_comment=[]

# %%
comments_tags=driver.find_elements_by_xpath("//div[@class='style-scope ytd-comment-renderer']")
comments_tags[0:500]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="39c5d70e-9c65-4247-87a8-73889bb8e7c9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="265175ec-faa4-445f-8fe5-787c87303b7a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="179fc201-d503-4575-8a21-c15b1d3b228d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="bd816364-634d-4093-80cc-71e1adb5616f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="0e0e26e0-2745-4359-bf9f-013ca395bd3d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="fa92a253-4804-4501-bb31-9cab3513b231")>,
# ...

# %%
for i in comments_tags:
    comment=i.text
    Comments.append(comment)
Comments[0:500]
# Out:
# ['',
#  '',
#  'Vaibhav Joshi\n13 days ago\nI wish I could watch the whole movie again in 4k .... The fights where phenomenal\n78\nREPLY',
#  '',
#  'Vaibhav Joshi\n13 days ago\nI wish I could watch the whole movie again in 4k .... The fights where phenomenal\n78\nREPLY',
#  'Vaibhav Joshi\n13 days ago',
#  '',
#  'Vaibhav Joshi\n13 days ago',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'alejandro benedini\n7 days ago\nImagine if Jameson worked for hydra after all this time. That would explain hos attitude towards spiderman through all of the films. Or maybe he just really hates his guts Lmao\n13\nREPLY',
#  '',
#  'alejandro benedini\n7 days ago\nImagine if Jameson worked for hydra after all this time. That would explain hos attitude towards spiderman through all of the films. Or maybe he just really hates his guts Lmao\n13\nREPLY',
#  'alejandro benedini\n7 days ago',
#  '',
#  'alejandro benedini\n7 days ago',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
commentupvote_tags=driver.find_elements_by_xpath("//yt-icon[@class='style-scope ytd-toggle-button-renderer']")
commentupvote_tags[0:500]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="61f9a3cd-5fd1-4306-8cfd-a2168434e42a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="ad16cda7-1be6-4919-8894-c231fce70ec0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="5eb0f7b0-6446-4653-b7d1-987fb2b7a72d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="77a85d3e-efa8-4bab-9240-1cda785f3f74")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="9dfa6a7b-15b0-4f67-ba78-423fd66fee17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="0b76124f-6f26-40dc-9cde-13ea8049cc98")>,
# ...

# %%
for i in commentupvote_tags:
    Commentupvotes=i.text
    Comment_upvote.append(Commentupvotes)
Comment_upvote[0:500]
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
time_tags=driver.find_elements_by_xpath("//a[@class='yt-simple-endpoint style-scope yt-formatted-string']")
time_tags[0:500]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="2362e333-ebc4-472b-9e03-3e965faff9d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="85a67d3b-73da-4a05-8901-4340a292c74e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="72e07458-e6f0-4342-964d-04d43b29f9df")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="d470b790-df61-47b1-8a26-5b7621fb179d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="dca3a1cd-a1b3-4bd6-8dfd-02001ffcf301")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18bafbd345330497d0d776062759e69f", element="69625fc5-ebcf-406f-9aae-d6cab181a124")>,
# ...

# %%
for i in time_tags:
    timeofcomment=i.text
    Time_of_comment.append(timeofcomment)
Time_of_comment[0:500]
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'TrailerSpot',
#  '13 days ago',
#  '',
#  '7 days ago',
#  '',
#  '7 days ago',
#  '',
#  '7 days ago',
#  '',
#  '2 days ago',
#  '',
#  '2 weeks ago',
#  '',
#  '2 weeks ago',
#  '',
#  '6 days ago',
#  '',
#  '4 days ago',
#  '0:20',
#  '',
#  '4 days ago',
#  '',
#  '5 days ago',
#  '',
#  '6 days ago',
#  '',
#  '2 weeks ago',
#  '',
#  '11 days ago',
#  '',
#  '11 days ago',
#  '',
#  '2 weeks ago (edited)',
#  '',
#  '11 days ago',
#  '',
#  '2 weeks ago',
#  '',
#  '2 days ago',
#  '0:35',
#  '',
#  '6 days ago',
#  '',
#  '2 weeks ago',
#  '0:09',
#  '',
#  '4 days ago',
#  '',
#  '5 days ago',
#  '',
#  '2 weeks ago',
#  '',
#  '10 days ago',
#  '',
#  '7 days ago',
#  '0:35',
#  '',
#  '4 days ago',
#  '',
#  '6 days ago',
#  '',
# ...

# %%
#10th program

# %%
driver = webdriver.Chrome(r"C:/Users/Vidhya/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.hostelworld.com/')

# %%
search_location=driver.find_element_by_id('search-input-field')
search_location.send_keys("London")

# %%
search_btn=driver.find_element_by_xpath("//div[@class='label']")
search_btn.click()

# %%
search_btn=driver.find_element_by_xpath("//button[@class='button primary large']")
search_btn.click()

# %%
hostel_name=[]
distance_from_city_centre=[]
ratings=[]
total_reviews=[]
overall_reviews=[]
privates_from_price=[]
dorms_from_price=[]
facilities=[]
property_description=[]

# %%
name_tags=driver.find_elements_by_xpath("//h2[@class='title title-6']")
name_tags[0:30]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="9a25edae-11ab-4381-b0e8-5ce86c9c335a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="1b7b3bab-daa0-42dd-a95b-a124dad018c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="4ab47f93-a55c-451b-bc56-82381ca34597")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="dd87efa4-3850-4dba-88a7-119ffa13673b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="1b9b4364-bd33-4b03-88fd-35c3a39630d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="46769327-4e2a-4e15-83aa-b4726e1de726")>,
# ...

# %%
for i in name_tags:
    hostelname=i.text
    hostel_name.append(hostelname)
hostel_name[0:30]
# Out:
# ['Mornington Camden',
#  'Smart Russell Square Hostel',
#  'Smart Camden Inn Hostel',
#  'Selina Camden',
#  'Queen Elizabeth Chelsea',
#  'Pickwick Hall',
#  'New Cross Inn Hostel',
#  'No.8 Willesden Hostel London',
#  'Safestay London Elephant & Castle',
#  'Barmy Badger Backpackers',
#  'The London Home Hostel',
#  'No.8 Seven Sisters',
#  'Burlington Residence',
#  'Park Villa',
#  'Astor Hyde Park',
#  "Wombat's The City Hostel London",
#  "St Christopher's Greenwich",
#  "St Christopher's Oasis-Female Only",
#  "St Christopher's Camden",
#  "St Christopher's Shepherds Bush",
#  "St Christopher's Hammersmith",
#  "St Christopher's Inn - Liverpool Street",
#  "St Christopher's Inn - London Bridge",
#  'PubLove @ The White Ferry, Victoria',
#  'Smart Hyde Park Inn Hostel',
#  'Smart Hyde Park View Hostel',
#  'Safestay London Kensington Holland Park',
#  'Urbany Hostel London',
#  'Astor Kensington',
#  'Phoenix Hostel']

# %%
name1_tags=driver.find_elements_by_xpath("//h2[@class='title title-6']")
name1_tags[0:30]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="5bd7867e-fd79-4b46-b8eb-27b23d73b2c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="069deb4d-b703-42df-99b9-81838b34760a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="de4c0362-e971-4952-ad49-5a3992e6ede7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="f0aa5a68-a72f-453f-896e-ea68ee777abd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="8ee5e044-bf75-4035-bec9-aa93ddde31d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="e8e53696-29c2-459a-b884-1226a668cd7b")>,
# ...

# %%
for i in name1_tags:
    hostelname1=i.text
    hostel_name.append(hostelname1)
hostel_name[0:30]
# Out:
# ['Mornington Camden',
#  'Smart Russell Square Hostel',
#  'Smart Camden Inn Hostel',
#  'Selina Camden',
#  'Queen Elizabeth Chelsea',
#  'Pickwick Hall',
#  'New Cross Inn Hostel',
#  'No.8 Willesden Hostel London',
#  'Safestay London Elephant & Castle',
#  'Barmy Badger Backpackers',
#  'The London Home Hostel',
#  'No.8 Seven Sisters',
#  'Burlington Residence',
#  'Park Villa',
#  'Astor Hyde Park',
#  "Wombat's The City Hostel London",
#  "St Christopher's Greenwich",
#  "St Christopher's Oasis-Female Only",
#  "St Christopher's Camden",
#  "St Christopher's Shepherds Bush",
#  "St Christopher's Hammersmith",
#  "St Christopher's Inn - Liverpool Street",
#  "St Christopher's Inn - London Bridge",
#  'PubLove @ The White Ferry, Victoria',
#  'Smart Hyde Park Inn Hostel',
#  'Smart Hyde Park View Hostel',
#  'Safestay London Kensington Holland Park',
#  'Urbany Hostel London',
#  'Astor Kensington',
#  'Phoenix Hostel']

# %%
distance_tags=driver.find_elements_by_xpath("//a[@class='show-on-map']")
distance_tags[0:90]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="9735dc96-021e-4ba1-81af-93bf5616b894")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="7a69cfd2-d450-4c01-91a0-b430de6ba540")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="7bb50ae9-4d59-4251-9130-59b3de99c773")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="64291c4b-a886-4cf0-aa01-837793f74af2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="5e9dd855-e13f-4929-a833-2b2b1350cd73")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="9acb4e09-cd89-483d-b132-31285616ba0f")>,
# ...

# %%
for i in distance_tags:
    distance=i.text
    distance_from_city_centre.append(distance)
distance_from_city_centre[0:90]
# Out:
# ['Hostel - 4.1km from city centre Show on Map',
#  'Hostel - 2.6km from city centre Show on Map',
#  'Hostel - 4.4km from city centre Show on Map',
#  'Hostel - 5.5km from city centre Show on Map',
#  'Hostel - 5.7km from city centre Show on Map',
#  'Hostel - 2.3km from city centre Show on Map',
#  'Hostel - 6.1km from city centre Show on Map',
#  'Hostel - 10km from city centre Show on Map',
#  'Hostel - 1.7km from city centre Show on Map',
#  'Hostel - 5.5km from city centre Show on Map',
#  'Hostel - 8.2km from city centre Show on Map',
#  'Hostel - 9km from city centre Show on Map',
#  'Hostel - 7.1km from city centre Show on Map',
#  'Hostel - 6.3km from city centre Show on Map',
#  'Hostel - 4.3km from city centre Show on Map',
#  'Hostel - 3.6km from city centre Show on Map',
#  'Hostel - 7.6km from city centre Show on Map',
#  'Hostel - 1.8km from city centre Show on Map',
#  'Hostel - 4.3km from city centre Show on Map',
#  'Hostel - 7km from city centre Show on Map',
# ...

# %%
rating_tags=driver.find_elements_by_xpath("//div[@class='score orange big']")
rating_tags[0:90]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="6b002dee-5d87-48c1-ac64-fea40e1459fe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="7464e90f-32b0-4c71-8efe-a0856d9b7f4a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="4ab6f2b0-36b0-4f65-b392-e2307582bed8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="2ae57049-ca9e-46b3-8624-56cdfd354fcd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="0241392a-7e78-4fd4-8e5e-e6806591d7c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="2b37f388-cff4-418d-ab2f-413394c4a70e")>,
# ...

# %%
for i in rating_tags:
    rating=i.text
    ratings.append(rating)
ratings[0:90]
# Out:
# ['8.3\nFabulous\n44 Total Reviews',
#  '6.7\nGood\n9561 Total Reviews',
#  '8.4\nFabulous\n2731 Total Reviews',
#  '9.1\nSuperb\n13 Total Reviews',
#  '7.5\nVery Good\n3212 Total Reviews',
#  '9.0\nSuperb\n2273 Total Reviews',
#  '7.4\nVery Good\n1047 Total Reviews',
#  '7.5\nVery Good\n4630 Total Reviews',
#  '7.9\nVery Good\n4020 Total Reviews',
#  '9.3\nSuperb\n1687 Total Reviews',
#  '4.7\nRating\n253 Total Reviews',
#  '6.7\nGood\n3681 Total Reviews',
#  '9.2\nSuperb\n33 Total Reviews',
#  '8.3\nFabulous\n854 Total Reviews',
#  '8.6\nFabulous\n11381 Total Reviews',
#  '8.8\nFabulous\n13358 Total Reviews',
#  '6.7\nGood\n3152 Total Reviews',
#  '8.0\nFabulous\n617 Total Reviews',
#  '7.2\nVery Good\n3729 Total Reviews',
#  '8.6\nFabulous\n639 Total Reviews',
#  '7.6\nVery Good\n3967 Total Reviews',
#  '8.1\nFabulous\n374 Total Reviews',
#  '8.0\nFabulous\n3252 Total Reviews',
#  '8.4\nFabulous\n185 Total Reviews',
#  '6.8\nGood\n6258 Total Reviews',
# ...

# %%
totalreviews_tags=driver.find_elements_by_xpath("//div[@class='reviews']")
totalreviews_tags[0:90]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="cb4bcd41-2b52-47dc-aa46-716fe6af214a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="a44cceb5-45a2-421e-869d-5d58a4acaac0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="c753adec-8cd9-466a-b91b-bb4c41f2a5ad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="977d38b2-cce0-4e69-bd42-dfb2ae1598c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="bf70812a-829c-4688-bbdf-05eec3c09d46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="740c4c15-f85b-47cc-bf5c-d8ef4aff2cea")>,
# ...

# %%
for i in totalreviews_tags:
    totalreviews=i.text
    total_reviews.append(totalreviews)
total_reviews[0:90]
# Out:
# ['44 Total Reviews',
#  '9561 Total Reviews',
#  '2731 Total Reviews',
#  '13 Total Reviews',
#  '3212 Total Reviews',
#  '2273 Total Reviews',
#  '1047 Total Reviews',
#  '4630 Total Reviews',
#  '4020 Total Reviews',
#  '1687 Total Reviews',
#  '253 Total Reviews',
#  '3681 Total Reviews',
#  '33 Total Reviews',
#  '854 Total Reviews',
#  '11381 Total Reviews',
#  '13358 Total Reviews',
#  '3152 Total Reviews',
#  '617 Total Reviews',
#  '3729 Total Reviews',
#  '639 Total Reviews',
#  '3967 Total Reviews',
#  '374 Total Reviews',
#  '3252 Total Reviews',
#  '185 Total Reviews',
#  '6258 Total Reviews',
#  '4514 Total Reviews',
#  '1105 Total Reviews',
#  '183 Total Reviews',
#  '6341 Total Reviews',
#  '3474 Total Reviews']

# %%
overallreviews_tags=driver.find_elements_by_xpath("//div[@class='keyword']")
overallreviews_tags[0:90]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="f2072b50-cf84-43f0-8169-9efc13cd1ecd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="3ba83720-8db6-4b8a-877c-8c4db1bbf60f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="817659d5-fac6-4635-ba2e-4ec231cf0144")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="eec46e67-d86c-47d2-bdc1-9c502d974b1c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="04882e39-77c3-4c66-bf93-dafeafbe9752")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="f8c1824a-a32e-48e7-b3cd-a56a27571403")>,
# ...

# %%
for i in overallreviews_tags:
    overallreviews=i.text
    overall_reviews.append(overallreviews)
overall_reviews[0:90]
# Out:
# ['Superb',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Good',
#  'Fabulous',
#  'Superb',
#  'Very Good',
#  'Superb',
#  'Very Good',
#  'Very Good',
#  'Very Good',
#  'Superb',
#  'Rating',
#  'Good',
#  'Superb',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Good',
#  'Fabulous',
#  'Very Good',
#  'Fabulous',
#  'Very Good',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Good',
#  'Very Good',
#  'Fabulous',
#  'Superb',
#  'Very Good',
#  'Very Good']

# %%
price_tags=driver.find_elements_by_xpath("//div[@class='price title-5']")
price_tags[0:90]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="df2d4af0-45bf-4fd1-ad47-780464cf4438")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="6563173c-df2f-42fd-a00b-0b5c90338503")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="1178d4f4-5354-4c89-b24f-56505216ee4c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="7d3a9d46-181e-4d20-8cd0-d950e74e5c09")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="de32ab9a-363f-4c94-9140-10f6579e9b66")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="213bf6b1-b868-4310-8eb2-5b419e239e71")>,
# ...

# %%
for i in price_tags:
    price=i.text
    privates_from_price.append(price)
privates_from_price[0:90]
# Out:
# ['Rs3151',
#  'Rs9920',
#  'Rs1157',
#  'Rs6372',
#  'Rs1458',
#  'Rs17714',
#  'Rs6181.75 Rs5254',
#  'Rs2476',
#  'Rs1528',
#  'Rs6633',
#  'Rs5391.62 Rs4852',
#  'Rs1534.78 Rs1381',
#  'Rs2072',
#  'Rs715',
#  'Rs6784',
#  'Rs2111',
#  'Rs6097',
#  'Rs2345',
#  'Rs7538',
#  'Rs2915',
#  'Rs749',
#  'Rs5662',
#  'Rs3316.72 Rs2653',
#  'Rs6965',
#  'Rs2874',
#  'Rs2010',
#  'Rs10914.46 Rs9059',
#  'Rs3127.77 Rs2346',
#  'Rs6099.64 Rs5490',
#  'Rs1200.87 Rs1081',
#  'Rs5727.39 Rs5155',
#  'Rs1551.16 Rs1396',
#  'Rs1476.7 Rs1329',
#  'Rs5801.84 Rs5222',
#  'Rs1334.5 Rs1201',
#  'Rs5280.7 Rs4753',
#  'Rs1253.36 Rs1128',
#  'Rs1700.06 Rs1530',
#  'Rs5429.6 Rs4887',
#  'Rs1551.16 Rs1396',
#  'Rs2278',
#  'Rs1187',
#  'Rs4500',
#  'Rs1247',
#  'Rs6784',
#  'Rs2382',
#  'Rs8020',
#  'Rs1869',
#  'Rs8476',
#  'Rs2010',
#  'Rs1407.09 Rs1337']

# %%
facilities_tags=driver.find_elements_by_xpath("//span[@class='label']")
facilities_tags[0:90]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="28d8d4b4-9c17-4120-8312-756964ad87c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="c97ad3c5-3e01-4256-937c-1c5fd62caa45")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="852c8ce4-a4e5-45d4-a06f-266c1810c07e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="bb2b8722-bae3-438b-a06a-27d8f704994f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="440a2ae3-0645-41fb-96ef-40b2748d5a95")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="4de212eb-d585-407f-8d79-1c15013a575b")>,
# ...

# %%
for i in facilities_tags:
    facilities1=i.text
    facilities.append(facilities1)
facilities[0:90]
# Out:
# ['Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Free Breakfast',
#  'Free WiFi',
#  'Free Breakfast',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free Breakfast',
#  'Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free Breakfast',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free Breakfast',
# ...

# %%
propertydescription_tags=driver.find_elements_by_xpath("//div[@class='content collapse-content']")
propertydescription_tags[0:90]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="49cc4b2a-b942-4317-99a3-ef70260d98ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="019be4cd-aa98-4c20-aab4-0769f64a9a0f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6b1562fddaac928127e83e0905e575c8", element="c0339d74-38c6-4d77-b0ab-879ac6fda9b9")>]

# %%
for i in propertydescription_tags:
    propertydescription=i.text
    property_description.append(propertydescription)
property_description[0:90]
# Out:
# ['Mornington Camden Hostel is a high class spacious town house with a lovely warm atmosphere. Everything is new. \nThe staff are very friendly and helpful. We have a nice lounge with a TV, and a Bar, and restaurant with cheap high quality food. \n\nMany restaurants, traditional pubs and bars are nearby and breakfast and snacks can be purchased next door in our sister building, the Crescent Cafe, at a discount. The renowned Camden market, Regents Park, London Zoo and Fitzrovia are within walking distance. Kings Cross, Euston and St Pancras (Eurostar) are within easy reach. \n\nAll beds have\nUSB charging points on the electrical sockets. \nFree Linen and Towels. \nFree Lockers\nFull Privacy\nPersonal Lamp\nFull use of a private garden\nFree Coffee and Tea\nFree Washing Machine use\nFree bag storage\n24 hour access if arranged with us beforehand\n\n\nThe Hurdwick policies & conditions;\n\nCancellation policy: 24h before arrival 6 PM\n\nCheck in from 13:00 to 23:00 .\nCheck out before 1
# ...
